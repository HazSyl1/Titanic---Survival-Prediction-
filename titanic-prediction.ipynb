# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
data=pd.read_csv("/kaggle/input/titanic/train.csv")

# %%
data.head(5)

# %%
data.count()

# %%
data.isna()

# %%
NA = pd.DataFrame(data=[data.isna().sum().tolist(), ["{:.2f}".format(i)+'%' \
           for i in (data.isna().sum()/data.shape[0]*100).tolist()]], 
           columns=data.columns, index=['NA Count', 'NA Percent']).transpose()

NA.style.background_gradient(cmap="Pastel1_r", subset=['NA Count'])

# %%
data_1=data.drop(['Cabin','Name'],axis='columns')

# %%
data_1['Age'].isna().sum()

# %%
imp = SimpleImputer(strategy='mean')
data_1['Age'] = imp.fit_transform(data_1['Age'].values.reshape(-1, 1) )

data_1['Age'].isna().sum()

# %%
data_1.isna().sum()

# %%
data_1['Embarked']

# %%
data_1['Embarked'].isna().sum()

# %%
data_1.isna().sum()

# %%
df = data_1[data_1['Embarked'].notna()]

# %%
df.isna().sum()

# %%
df.head(5)

# %%
df['Parch'].value_counts()

# %%
df=df.drop('Ticket',axis='columns')

# %%
df.head(5)

# %%
df.corr

# %%
df=df.drop('PassengerId',axis='columns')

# %%
df

# %%
df['Sex'] = df['Sex'].astype('category')
df['Sex'] = df['Sex'].cat.codes

# %%
df['Embarked'] = df['Embarked'].astype('category')
df['Embarked'] = df['Embarked'].cat.codes

# %%
df.Embarked.head(5)

# %%
df.Embarked.unique()

# %%
df.head(5)

# %%
df.isna().sum()

# %%
X=df.values[:,1:9]

# %%
Y=df.values[:,0]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=40)

# %%
X_train.shape

# %%
X_test.shape

# %%
X_train.shape[0]+X_test.shape[0] == df.shape[0]

# %%
clf_entropy=DecisionTreeClassifier(criterion='entropy',random_state=40)

# %%
clf_entropy.fit(X_train,y_train)

# %%
pred=clf_entropy.predict(X_test)
pred

# %%
acc=accuracy_score(y_test,pred)
print(f"Accuracy:{acc}")
